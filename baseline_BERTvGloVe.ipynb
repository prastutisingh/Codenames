# %%
import numpy as np
import pandas as pd
from scipy import spatial
from random import sample
import copy
import re
import nltk
from sklearn.metrics.pairwise import cosine_similarity
from scipy import spatial

# %%
# Import encoding dictionaries. i.e. bert_dict['cat'] = [0.5, -.4, 0.001,...]
bert_dict = np.load('bert.npy', allow_pickle = True); bert_dict = bert_dict[()] #This originally contains 42923 words
glove_dict = np.load('glove.npy', allow_pickle = True); glove_dict = glove_dict[()] #This originally contains 27296 words

# %%
# Part of speech tagging for bert_dict, removing everything that is not a noun or proper noun
bert_dict_copy = bert_dict.copy()
for key in bert_dict_copy:  
    tag = nltk.pos_tag([key.strip()])[0][1]
    if tag not in ['NN', 'NNP']: 
        del bert_dict[key]

# %%
# Import list of codenames words
codenames_words = []
with open("./codenames_words.txt", 'r') as f:
    for line in f:
        codenames_words.append(line.strip())

# %%
# Remove codenames words not in embeddings
def removeInvalidCodenames(embeddings, codenames_words):
    removed_words = []
    for item in codenames_words:
        if item not in embeddings:
            removed_words.append(item)
            codenames_words.remove(item)
    #print('Words removed from codenames are', removed_words)
    return codenames_words

codenames_words_glove = removeInvalidCodenames(glove_dict, codenames_words)
codenames_words_bert = removeInvalidCodenames(bert_dict, codenames_words)

# %%
# Turn BERT into indexable embeddings
all_bert_words = list(bert_dict.keys())
word_to_idx_bert = dict(zip(all_bert_words, range(len(all_bert_words))))
idx_to_word_bert = dict(zip(range(len(all_bert_words)), all_bert_words))

# Turn GLOVE into indexable embeddings
all_glove_words = list(glove_dict.keys())
word_to_idx_glove = dict(zip(all_glove_words, range(len(all_glove_words))))
idx_to_word_glove = dict(zip(range(len(all_glove_words)), all_glove_words))

# Get indexes for codenames words
codenames_words_idxs_bert = np.array([word_to_idx_bert[word] for word in codenames_words])
codenames_words_idxs_glove = np.array([word_to_idx_glove[word] for word in codenames_words])

# Get BERT embeddings as giant matrix
bert_embedding = [bert_dict[word] for word in all_bert_words]
bert_embedding = np.vstack(bert_embedding) # shape = (27296, 768)

glove_embedding = [glove_dict[word] for word in all_glove_words]
glove_embedding = np.vstack(glove_embedding) # shape = (27296, 300)

# %%
from scipy.special import softmax

# Returns list of random indexes from indexes of codenames words
def generate_single_board(codenames_words_idxs, idx_to_word): 
    board = np.random.choice(codenames_words_idxs, 2)
    while len(board) != len(set(board)): #this makes sure you dont choose the same two words for the board
        board = np.random.choice(codenames_words_idxs, 2)
    print('We are looking at board:', [idx_to_word[index] for index in board])
    return board

# Calculates prob. distribution (using softmax) over entire vocabulary for a single board
def clue_dist_for_one_board(embedding, idx_to_word, board, temperature = 1):
    '''
    embedding: V x [embedding_size = 768]
    board: (3,) [indices of good words in all_bert_words]
    scoring: either cosine or euclidean
    temperature: sampling smoothing over prob. distribution
    '''
    
    V, K = embedding.shape
    board_embedding = embedding[board] # shape = (2 x 768)
    # Calculate score for each word in vocabulary using the specified scoring function
    score_euclidean = -((board_embedding.reshape(1, 2, K) - embedding.reshape(V, 1, K)) ** 2).sum(2).sum(1) # shape V
    score_cosine = np.zeros(V)
    for i in range(V):
        score_cosine[i] = -spatial.distance.cosine(board_embedding[0,:], embedding[i,:]) + spatial.distance.cosine(board_embedding[1,:], embedding[i,:])
    score_cosine = np.asarray(score_cosine)
    
    # Penalize scores for good words

    score_euclidean[board] -= 1e6
    score_cosine[board] -= 1e6
    top_indices_euclidean = score_euclidean.argsort()[-100:][::-1]
    top_indices_cosine = score_cosine.argsort()[-100:][::-1]
    top_clues_euclidean = [idx_to_word[index] for index in top_indices_euclidean]
    top_clues_cosine = [idx_to_word[index] for index in top_indices_cosine]
    
    return top_clues_euclidean, top_clues_cosine

# %%
board = generate_single_board(codenames_words_idxs, idx_to_word); #generates the two indices of the board
print(board)
clue_dist_for_one_board(bert_embedding, idx_to_word, board, scoring = 'cosine', temperature = 1) #outputs the softmax scorse for all the potential clues
# Out:
# We are looking at board: ['france', 'dog']
# [887 350]
# The top cosine clues are: ['dijon', 'suisse', 'mauritania', 'visage', 'guelph', 'guernsey', 'sauvignon', 'vuitton', 'clarkson', 'lille']
# The top euclidean clues are: ['martinique', 'bike', 'labrador', 'newfoundland', 'bicycle', 'lizard', 'squirrel', 'quebec', 'québec', 'lion']

# %%
# Read data from txt file
def read_data(examples, data): 
    '''
    Takes in dataset from examples and data (make sure they're for the same data!!!) and appends each example to
    a matrix. 
    For example, 
        board = 'cat', 'dog' (from examples)
        gold_word = 'pet' (from data)
    Will be appended as: 
        [[word_to_idx['cat], word_to_idx['dog']], [word_to_idx['dog']]]
    '''
    data_matrix = []
    with open(examples) as examples, open(data) as data:
        for line1, line2 in zip(examples, data):
            input_line_1 = line1.split('.')
            good_words = input_line_1[1].strip('\n').split(',')[:2]
            
            input_line_2 = line2.split('.')
            gold_word = input_line_2[1].strip()
            
            if input_line_1[0] == input_line_2[0]: 
                board = [word_to_idx[word.strip()] for word in good_words]
                if gold_word == 'No good clues': 
                    continue
            
                try: 
                    data_matrix.append([board, [word_to_idx[gold_word]]])
                except: 
                    continue
            else: 
                print(input_line_1[0])
                print(input_line_2[0])
                print('Uh oh, misaligment!')
                break
            
    return data_matrix

# %%
from random import randint

def baseline_accuracy(data_list, idx_to_word, embedding):
    ''' takes in a data_list of form [[boardword1, boardword2], truth]
    recovers top 100 clues from both models
    checks if truth is in those top 100 
    '''
    data_length = len(data_list)
    data_list = data_list[:data_length]
    euclidean_score = 0
    cosine_score = 0
    random_score = 0
    iteration = 1
    for example in data_list:
        rand_indices = np.random.randint(0, len(idx_to_word), 10)
        rand_words = [idx_to_word[index] for index in rand_indices]
        board_indices = example[0]
        chosen_clue = example[1]
        print(iteration, 'New data!', [idx_to_word[index] for index in board_indices], idx_to_word[chosen_clue[0]])
        if idx_to_word[chosen_clue[0]] in rand_words:
            random_score += 1
            print('Random got it!', random_score/iteration)
        top_clues_euclidean, top_clues_cosine = clue_dist_for_one_board(embedding, idx_to_word, board_indices, temperature = 1) #outputs the softmax scorse for all the potential clues
        if idx_to_word[chosen_clue[0]] in top_clues_euclidean:
            euclidean_score += 1
            print('Euclidean got it!', euclidean_score/iteration)
        if idx_to_word[chosen_clue[0]] in top_clues_cosine:
            cosine_score += 1
            print('Cosine got it!', cosine_score/iteration)
        iteration += 1
    print('Euclidean accuracy is', euclidean_score/data_length)
    print('Cosine accuracy is', cosine_score/data_length)
    print('Random accuray is!', random_score/data_length)

# %%
data_list = read_data('examples_all_20200313.txt', 'data_all_20200313.txt')
baseline_accuracy(data_list, idx_to_word_glove, glove_embedding)
# Out:
# 1 New data! ['engine', 'park'] car
# 2 New data! ['millionaire', 'mass'] gold
# 3 New data! ['lawyer', 'doctor'] profession
# Euclidean got it! 0.3333333333333333
# 4 New data! ['forest', 'queen'] elf
# 5 New data! ['giant', 'lemon'] peach
# Euclidean got it! 0.4
# 6 New data! ['hotel', 'ghost'] haunt
# 7 New data! ['europe', 'film'] venice
# 8 New data! ['glove', 'file'] hand
# Euclidean got it! 0.375
# 9 New data! ['capital', 'lab'] grant
# 10 New data! ['eagle', 'trip'] fly
# Euclidean got it! 0.4
# 11 New data! ['yard', 'berry'] bush
# 12 New data! ['kangaroo', 'park'] outback
# 13 New data! ['time', 'center'] sun
# 14 New data! ['box', 'egypt'] pyramid
# 15 New data! ['kid', 'glove'] tear
# 16 New data! ['time', 'wave'] moon
# 17 New data! ['berry', 'washington'] apple
# 18 New data! ['angel', 'spike'] name
# 19 New data! ['lab', 'hotel'] place
# Euclidean got it! 0.2631578947368421
# 20 New data! ['amazon', 'novel'] bookstore
# 21 New data! ['fish', 'himalaya'] kerala
# 22 New data! ['worm', 'cricket'] field
# 23 New data! ['kid', 'triangle'] tricycle
# 24 New data! ['teacher', 'forest'] ranger
# 25 New data! ['water', 'jet'] ski
# 26 New data! ['gas', 'shot'] liquid
# 27 New data! ['fish', 'hook'] bait
# Euclidean got it! 0.2222222222222222
# 28 New data! ['net', 'park'] basketball
# 29 New data! ['spike', 'berlin'] club
# 30 New data! ['hole', 'club'] golf
# Euclidean got it! 0.23333333333333334
# 31 New data! ['washer', 'europe'] ikea
# 32 New data! ['bow', 'millionaire'] king
# 33 New data! ['queen', 'amazon'] ant
# 34 New data! ['hospital', 'vacuum'] clean
# 35 New data! ['mass', 'england'] church
# 36 New data! ['time', 'mammoth'] prehistoric
# 37 New data! ['jet', 'berlin'] airplane
# Euclidean got it! 0.21621621621621623
# Cosine got it! 0.02702702702702703
# 38 New data! ['glove', 'truck'] drive
# 39 New data! ['novel', 'paper'] book
# Euclidean got it! 0.23076923076923078
# 40 New data! ['duck', 'witch'] float
# 41 New data! ['tooth', 'hospital'] dentist
# Euclidean got it! 0.24390243902439024
# 42 New data! ['leprechaun', 'turkey'] holiday
# 43 New data! ['lion', 'horn'] africa
# 44 New data! ['pumpkin', 'ninja'] halloween
# Euclidean got it! 0.25
# 45 New data! ['fighter', 'pound'] beat
# Euclidean got it! 0.26666666666666666
# 46 New data! ['pie', 'pit'] cherry
# 47 New data! ['mexico', 'china'] country
# Euclidean got it! 0.2765957446808511
# 48 New data! ['england', 'organ'] church
# 49 New data! ['ring', 'king'] gold
# 50 New data! ['park', 'wake'] cemetery
# 51 New data! ['bridge', 'play'] card
# 52 New data! ['beat', 'cook'] egg
# 53 New data! ['park', 'horn'] rhino
# 54 New data! ['card', 'crown'] king
# 55 New data! ['shark', 'straw'] liquid
# 56 New data! ['turkey', 'witch'] autumn
# 57 New data! ['sound', 'cycle'] frequency
# 58 New data! ['pound', 'foot'] measurement
# 59 New data! ['bark', 'box'] doghouse
# 60 New data! ['park', 'dog'] walk
# Euclidean got it! 0.23333333333333334
# 61 New data! ['disease', 'head'] meningitis
# 62 New data! ['gold', 'tie'] win
# 63 New data! ['seal', 'lap'] swim
# 64 New data! ['film', 'cotton'] industry
# 65 New data! ['draft', 'paste'] word
# 66 New data! ['pound', 'square'] yard
# 67 New data! ['air', 'laser'] plasma
# 68 New data! ['school', 'theater'] facility
# 69 New data! ['play', 'straw'] doll
# 70 New data! ['model', 'palm'] hand
# Euclidean got it! 0.21428571428571427
# 71 New data! ['bank', 'mint'] money
# Euclidean got it! 0.22535211267605634
# Cosine got it! 0.028169014084507043
# 72 New data! ['fence', 'war'] border
# 73 New data! ['space', 'battery'] tesla
# 74 New data! ['plane', 'strike'] missile
# 75 New data! ['cycle', 'nurse'] round
# 76 New data! ['moscow', 'gas'] oil
# 77 New data! ['pin', 'dress'] tailor
# 78 New data! ['pistol', 'strike'] target
# Euclidean got it! 0.21794871794871795
# 79 New data! ['fork', 'battery'] potato
# 80 New data! ['light', 'beach'] bonfire
# 81 New data! ['date', 'chick'] girlfriend
# Euclidean got it! 0.2222222222222222
# 82 New data! ['belt', 'strike'] hit
# Euclidean got it! 0.23170731707317074
# 83 New data! ['figure', 'buffalo'] cowboy
# 84 New data! ['scorpion', 'sound'] hiss
# 85 New data! ['bar', 'agent'] undercover
# 86 New data! ['glass', 'tube'] bong
# 87 New data! ['school', 'dance'] prom
# 88 New data! ['revolution', 'opera'] bastille
# 89 New data! ['tap', 'oil'] drill
# 90 New data! ['pound', 'berlin'] euro
# 91 New data! ['lab', 'doctor'] diagnosis
# 92 New data! ['war', 'pin'] map
# 93 New data! ['pie', 'parachute'] sky
# 94 New data! ['bermuda', 'octopus'] beach
# 95 New data! ['hotel', 'canada'] whistler
# 96 New data! ['sound', 'spot'] radar
# 97 New data! ['ring', 'log'] tree
# 98 New data! ['tooth', 'stick'] pick
# 99 New data! ['hole', 'rock'] mine
# 100 New data! ['field', 'diamond'] mine
# 101 New data! ['part', 'crown'] hair
# 102 New data! ['pan', 'screen'] critic
# 103 New data! ['spine', 'sink'] slump
# 104 New data! ['web', 'track'] advertisement
# 105 New data! ['buffalo', 'cloak'] leather
# 106 New data! ['car', 'eye'] sensor
# 107 New data! ['ham', 'tube'] sausage
# Euclidean got it! 0.18691588785046728
# Cosine got it! 0.028037383177570093
# 108 New data! ['lemon', 'lead'] battery
# 109 New data! ['cricket', 'spring'] grass
# 110 New data! ['arm', 'match'] wrestling
# 111 New data! ['water', 'conductor'] salt
# Cosine got it! 0.036036036036036036
# 112 New data! ['spike', 'belt'] stud
# 113 New data! ['eagle', 'calf'] animal
# 114 New data! ['europe', 'cap'] euro
# Euclidean got it! 0.18421052631578946
# 115 New data! ['note', 'point'] pencil
# 116 New data! ['nut', 'deck'] backyard
# 117 New data! ['scorpion', 'fan'] ninja
# 118 New data! ['log', 'gas'] fire
# Euclidean got it! 0.1864406779661017
# 119 New data! ['bond', 'row'] element
# 120 New data! ['fly', 'kid'] kite
# 121 New data! ['laser', 'pitch'] doppler
# 122 New data! ['dress', 'ruler'] mantle
# 123 New data! ['server', 'battery'] laptop
# Euclidean got it! 0.18699186991869918
# 124 New data! ['draft', 'fan'] wind
# 125 New data! ['press', 'glass'] pressure
# 126 New data! ['microscope', 'band'] electron
# Cosine got it! 0.03968253968253968
# 127 New data! ['tail', 'night'] raccoon
# 128 New data! ['arm', 'shoe'] foot
# Euclidean got it! 0.1875
# 129 New data! ['bow', 'part'] hair
# 130 New data! ['mole', 'revolution'] benedict
# 131 New data! ['soul', 'change'] redemption
# 132 New data! ['berry', 'plate'] pie
# Euclidean got it! 0.1893939393939394
# 133 New data! ['tap', 'lap'] dance
# 134 New data! ['apple', 'bomb'] round
# 135 New data! ['shadow', 'crown'] government
# 136 New data! ['brush', 'stadium'] horse
# 137 New data! ['hook', 'tick'] parasite
# 138 New data! ['princess', 'watch'] guard
# 139 New data! ['dog', 'teacher'] yoga
# 140 New data! ['scale', 'mercury'] temperature
# 141 New data! ['change', 'tower'] guard
# 142 New data! ['genius', 'knife'] killer
# Euclidean got it! 0.18309859154929578
# 143 New data! ['spell', 'square'] circle
# Euclidean got it! 0.1888111888111888
# 144 New data! ['doctor', 'poison'] medicine
# 145 New data! ['hand', 'paste'] cream
# 146 New data! ['church', 'log'] lady
# 147 New data! ['king', 'foot'] gout
# 148 New data! ['cross', 'train'] loss
# 149 New data! ['plate', 'dance'] buffet
# 150 New data! ['paper', 'tablet'] notebook
# Euclidean got it! 0.18666666666666668
# 151 New data! ['wake', 'track'] alarm
# 152 New data! ['spy', 'tokyo'] bond
# 153 New data! ['moscow', 'vacuum'] revolution
# 154 New data! ['microscope', 'crown'] petit
# 155 New data! ['deck', 'point'] position
# 156 New data! ['fair', 'jet'] class
# 157 New data! ['figure', 'nail'] ballerina
# 158 New data! ['note', 'flute'] song
# 159 New data! ['stock', 'kid'] grocery
# 160 New data! ['honey', 'chest'] gold
# 161 New data! ['superhero', 'dice'] chance
# 162 New data! ['table', 'star'] tree
# 163 New data! ['note', 'flute'] song
# 164 New data! ['cell', 'moscow'] place
# 165 New data! ['light', 'dress'] sun
# 166 New data! ['fork', 'band'] tune
# Euclidean got it! 0.1746987951807229
# 167 New data! ['note', 'square'] rectangle
# 168 New data! ['penguin', 'church'] slip
# 169 New data! ['ninja', 'draft'] race
# 170 New data! ['mint', 'check'] bill
# 171 New data! ['palm', 'bomb'] throw
# 172 New data! ['flute', 'spine'] narrow
# 173 New data! ['force', 'revolution'] enemy
# 174 New data! ['mercury', 'snow'] temperature
# 175 New data! ['china', 'bug'] disease
# 176 New data! ['genius', 'jack'] rick
# 177 New data! ['round', 'calf'] fat
# 178 New data! ['head', 'wake'] dream
# 179 New data! ['bug', 'chest'] jungle
# 180 New data! ['tube', 'helicopter'] transportation
# 181 New data! ['square', 'post'] rectangle
# Cosine got it! 0.03314917127071823
# 182 New data! ['pyramid', 'crash'] scheme
# 183 New data! ['death', 'disease'] pneumonia
# 184 New data! ['atlantis', 'chair'] throne
# 185 New data! ['helicopter', 'grace'] heaven
# Euclidean got it! 0.16216216216216217
# 186 New data! ['calf', 'bug'] living
# 187 New data! ['germany', 'fire'] rome
# 188 New data! ['battery', 'space'] technology
# 189 New data! ['track', 'ambulance'] race
# Cosine got it! 0.037037037037037035
# 190 New data! ['fall', 'plane'] skydive
# 191 New data! ['tap', 'scientist'] water
# 192 New data! ['lab', 'needle'] injection
# 193 New data! ['cycle', 'spot'] footprint
# 194 New data! ['conductor', 'tokyo'] bullet
# 195 New data! ['vet', 'skyscraper'] broker
# 196 New data! ['link', 'web'] com
# 197 New data! ['file', 'helicopter'] scanner
# 198 New data! ['penguin', 'maple'] canada
# 199 New data! ['conductor', 'war'] tragedy
# 200 New data! ['pole', 'litter'] street
# 201 New data! ['gas', 'log'] fire
# Euclidean got it! 0.15422885572139303
# 202 New data! ['log', 'buffalo'] nature
# 203 New data! ['sink', 'cross'] dish
# 204 New data! ['sound', 'london'] island
# 205 New data! ['copper', 'lab'] material
# 206 New data! ['africa', 'block'] regime
# 207 New data! ['maple', 'bond'] wood
# Euclidean got it! 0.15458937198067632
# 208 New data! ['agent', 'lap'] dog
# 209 New data! ['cook', 'kid'] pizza
# 210 New data! ['ketchup', 'shop'] restaurant
# 211 New data! ['pyramid', 'bolt'] structure
# 212 New data! ['diamond', 'fence'] baseball
# 213 New data! ['match', 'field'] game
# 214 New data! ['plastic', 'hook'] hanger
# Euclidean got it! 0.1542056074766355
# 215 New data! ['change', 'trunk'] park
# 216 New data! ['cycle', 'antarctica'] cool
# 217 New data! ['fish', 'spike'] lizard
# 218 New data! ['europe', 'flute'] culture
# 219 New data! ['ketchup', 'china'] rice
# 220 New data! ['washer', 'gold'] steel
# 221 New data! ['march', 'yard'] spring
# 222 New data! ['ice', 'pan'] eat
# 223 New data! ['pistol', 'drill'] tool
# 224 New data! ['crash', 'turkey'] economy
# 225 New data! ['flute', 'pirate'] song
# 226 New data! ['london', 'crown'] england
# Euclidean got it! 0.1504424778761062
# 227 New data! ['opera', 'life'] fancy
# 228 New data! ['bear', 'ship'] giant
# 229 New data! ['worm', 'contract'] disease
# 230 New data! ['heart', 'mount'] surgery
# 231 New data! ['hawk', 'ruler'] eagle
# Euclidean got it! 0.15151515151515152
# Cosine got it! 0.03463203463203463
# 232 New data! ['mouse', 'disease'] plague
# Euclidean got it! 0.15517241379310345
# 233 New data! ['france', 'chest'] queen
# 234 New data! ['chest', 'line'] bra
# 235 New data! ['life', 'amazon'] river
# 236 New data! ['snowman', 'lap'] santa
# 237 New data! ['cap', 'snow'] cold
# 238 New data! ['diamond', 'greece'] wealth
# 239 New data! ['space', 'scientist'] astronaut
# Euclidean got it! 0.15481171548117154
# 240 New data! ['whip', 'ice'] sundae
# 241 New data! ['missile', 'crown'] war
# 242 New data! ['screen', 'spell'] potter
# 243 New data! ['mouth', 'fork'] food
# 244 New data! ['africa', 'bottle'] water
# 245 New data! ['belt', 'war'] wrestling
# 246 New data! ['berry', 'beat'] smoothie
# Cosine got it! 0.036585365853658534
# 247 New data! ['jet', 'trip'] ski
# 248 New data! ['spring', 'trip'] break
# Euclidean got it! 0.1532258064516129
# 249 New data! ['bow', 'head'] arrow
# Euclidean got it! 0.1566265060240964
# 250 New data! ['mount', 'limousine'] ride
# 251 New data! ['box', 'file'] folder
# Euclidean got it! 0.1593625498007968
# 252 New data! ['forest', 'ring'] tree
# Euclidean got it! 0.1626984126984127
# 253 New data! ['ball', 'racket'] tennis
# Euclidean got it! 0.16600790513833993
# 254 New data! ['penguin', 'flute'] march
# 255 New data! ['flute', 'palm'] hold
# Euclidean got it! 0.16862745098039217
# 256 New data! ['chair', 'spike'] electricity
# 257 New data! ['snowman', 'london'] coal
# 258 New data! ['tokyo', 'lion'] fish
# 259 New data! ['cover', 'himalayas'] cold
# 260 New data! ['glove', 'bell'] hand
# Euclidean got it! 0.16923076923076924
# 261 New data! ['gold', 'whip'] chain
# 262 New data! ['wave', 'fire'] element
# 263 New data! ['pool', 'hospital'] drown
# 264 New data! ['root', 'charge'] science
# 265 New data! ['tag', 'stadium'] game
# 266 New data! ['spring', 'forest'] bloom
# Euclidean got it! 0.16917293233082706
# 267 New data! ['star', 'missile'] sky
# 268 New data! ['cliff', 'bat'] cavern
# 269 New data! ['lap', 'table'] napkin
# 270 New data! ['ice', 'shoe'] ski
# 271 New data! ['bed', 'bermuda'] resort
# 272 New data! ['penguin', 'whale'] animal
# 273 New data! ['deck', 'greece'] view
# 274 New data! ['washington', 'button'] inauguration
# 275 New data! ['air', 'bat'] fly
# Euclidean got it! 0.16727272727272727
# 276 New data! ['slip', 'trip'] fall
# Euclidean got it! 0.17028985507246377
# 277 New data! ['soul', 'kid'] purity
# 278 New data! ['bow', 'fork'] spear
# Euclidean got it! 0.17266187050359713
# 279 New data! ['note', 'shadow'] reflection
# 280 New data! ['moon', 'plot'] trajectory
# 281 New data! ['drop', 'leprechaun'] rainbow
# Euclidean got it! 0.17437722419928825
# 282 New data! ['church', 'bank'] institution
# Euclidean got it! 0.1773049645390071
# 283 New data! ['knight', 'honey'] queen
# 284 New data! ['laser', 'pool'] reflection
# 285 New data! ['lock', 'nut'] bolt
# Euclidean got it! 0.17894736842105263
# 286 New data! ['part', 'alien'] ufo
# 287 New data! ['hotel', 'sound'] disturb
# 288 New data! ['key', 'millionaire'] vault
# 289 New data! ['whip', 'france'] lingerie
# 290 New data! ['centaur', 'whip'] mush
# 291 New data! ['princess', 'rabbit'] cinderella
# Euclidean got it! 0.17869415807560138
# Cosine got it! 0.03436426116838488
# 292 New data! ['foot', 'wind'] rhythm
# 293 New data! ['soul', 'concert'] music
# Euclidean got it! 0.18088737201365188
# 294 New data! ['cross', 'nurse'] medicine
# 295 New data! ['ground', 'iron'] ore
# 296 New data! ['tube', 'tokyo'] subway
# Euclidean got it! 0.18243243243243243
# 297 New data! ['microscope', 'draft'] nature
# 298 New data! ['ice', 'racket'] hockey
# Euclidean got it! 0.18456375838926176
# 299 New data! ['eagle', 'berlin'] nazi
# 300 New data! ['saturn', 'time'] space
# 301 New data! ['conductor', 'star'] music
# 302 New data! ['washer', 'cliff'] water
# 303 New data! ['octopus', 'ship'] water
# 304 New data! ['tag', 'shoe'] toe
# Euclidean got it! 0.18421052631578946
# 305 New data! ['spot', 'lab'] csi
# 306 New data! ['pitch', 'knife'] camp
# 307 New data! ['microscope', 'sock'] glove
# 308 New data! ['plate', 'iron'] armor
# 309 New data! ['pole', 'grass'] croquet
# 310 New data! ['pole', 'block'] sprint
# 311 New data! ['bat', 'bridge'] ledge
# 312 New data! ['mouse', 'tail'] rat
# Euclidean got it! 0.18269230769230768
# Cosine got it! 0.035256410256410256
# 313 New data! ['switch', 'moon'] pokemon
# 314 New data! ['turkey', 'parachute'] float
# 315 New data! ['degree', 'pass'] certificate
# 316 New data! ['chair', 'belt'] seat
# Euclidean got it! 0.18354430379746836
# 317 New data! ['spider', 'honey'] insect
# Euclidean got it! 0.1861198738170347
# 318 New data! ['beat', 'bell'] ring
# 319 New data! ['pool', 'dog'] paddle
# 320 New data! ['match', 'helicopter'] shootout
# 321 New data! ['bermuda', 'casino'] resort
# 322 New data! ['mine', 'bark'] detect
# 323 New data! ['table', 'grace'] prayer
# 324 New data! ['wake', 'kid'] school
# 325 New data! ['europe', 'yard'] meter
# 326 New data! ['cook', 'lock'] pantry
# 327 New data! ['ship', 'queen'] princess
# Euclidean got it! 0.1834862385321101
# 328 New data! ['temple', 'straw'] drink
# 329 New data! ['mass', 'chocolate'] creatine
# 330 New data! ['concert', 'mouse'] noise
# 331 New data! ['fair', 'port'] trade
# Cosine got it! 0.03625377643504532
# 332 New data! ['dinosaur', 'opera'] bygone
# 333 New data! ['screen', 'bill'] surface
# 334 New data! ['button', 'robot'] android
# 335 New data! ['slug', 'bottle'] ooze
# 336 New data! ['lab', 'glass'] vial
# 337 New data! ['bugle', 'star'] anthem
# 338 New data! ['change', 'watch'] time
# Euclidean got it! 0.1804733727810651
# 339 New data! ['ketchup', 'drop'] dip
# Euclidean got it! 0.18289085545722714
# 340 New data! ['mass', 'hood'] priest
# 341 New data! ['centaur', 'sock'] hoof
# 342 New data! ['cover', 'chocolate'] syrup
# 343 New data! ['europe', 'engine'] ferrari
# 344 New data! ['horse', 'cricket'] animal
# Cosine got it! 0.0377906976744186
# 345 New data! ['state', 'pitch'] address
# 346 New data! ['duck', 'grass'] mud
# 347 New data! ['calf', 'grass'] pasture
# Euclidean got it! 0.18155619596541786
# 348 New data! ['code', 'needle'] pin
# Euclidean got it! 0.1839080459770115
# 349 New data! ['table', 'circle'] bowls
# 350 New data! ['tooth', 'cook'] eat
# Euclidean got it! 0.18571428571428572
# 351 New data! ['organ', 'straw'] pipe
# 352 New data! ['space', 'part'] rocket
# 353 New data! ['laser', 'piano'] wave
# 354 New data! ['tokyo', 'lion'] fish
# 355 New data! ['cold', 'cliff'] iceland
# 356 New data! ['force', 'germany'] nazi
# 357 New data! ['opera', 'post'] building
# 358 New data! ['europe', 'time'] medieval
# 359 New data! ['dress', 'ivory'] luxury
# 360 New data! ['organ', 'boom'] loud
# 361 New data! ['point', 'tooth'] canine
# 362 New data! ['africa', 'cloak'] dark
# 363 New data! ['china', 'hawk'] crane
# Euclidean got it! 0.18181818181818182
# 364 New data! ['tie', 'superhero'] uniform
# 365 New data! ['press', 'block'] basketball
# 366 New data! ['row', 'boom'] fight
# 367 New data! ['washington', 'ninja'] guerilla
# 368 New data! ['center', 'gold'] ore
# 369 New data! ['yard', 'bermuda'] plantation
# 370 New data! ['yard', 'scientist'] fieldwork
# 371 New data! ['angel', 'theater'] clarence
# 372 New data! ['track', 'life'] plan
# 373 New data! ['millionaire', 'cloak'] petticoat
# 374 New data! ['cloak', 'hook'] pirate
# 375 New data! ['march', 'princess'] knight
# 376 New data! ['pie', 'mine'] greedy
# 377 New data! ['disease', 'part'] tumor
# 378 New data! ['mole', 'egypt'] dig
# 379 New data! ['witch', 'bat'] evil
# Euclidean got it! 0.17678100263852242
# Cosine got it! 0.036939313984168866
# 380 New data! ['lion', 'giant'] killer
# Euclidean got it! 0.17894736842105263
# 381 New data! ['alien', 'ship'] space
# Euclidean got it! 0.18110236220472442
# 382 New data! ['light', 'carrot'] salad
# 383 New data! ['crash', 'fire'] burn
# Euclidean got it! 0.18276762402088773
# 384 New data! ['ground', 'beijing'] beef
# 385 New data! ['ice', 'space'] cold
# Euclidean got it! 0.18441558441558442
# 386 New data! ['mail', 'roulette'] payday
# 387 New data! ['pumpkin', 'orange'] halloween
# Euclidean got it! 0.18604651162790697
# Cosine got it! 0.03875968992248062
# 388 New data! ['rock', 'scale'] weighty
# 389 New data! ['dragon', 'aztec'] sacrifice
# 390 New data! ['spring', 'draft'] training
# 391 New data! ['spot', 'jupiter'] storm
# 392 New data! ['square', 'piano'] keyboard
# 393 New data! ['round', 'london'] clock
# 394 New data! ['mug', 'ruler'] cup
# 395 New data! ['stream', 'boot'] wade
# 396 New data! ['link', 'root'] relationship
# 397 New data! ['play', 'piano'] music
# Euclidean got it! 0.18387909319899245
# 398 New data! ['bolt', 'triangle'] pointy
# 399 New data! ['button', 'school'] id
# 400 New data! ['ring', 'cat'] collar
# 401 New data! ['horse', 'nail'] shoe
# 402 New data! ['square', 'head'] block
# Euclidean got it! 0.18407960199004975
# 403 New data! ['bed', 'fire'] cozy
# 404 New data! ['buffalo', 'car'] carriage
# 405 New data! ['genius', 'air'] breezy
# 406 New data! ['bar', 'ship'] rum
# 407 New data! ['hospital', 'tie'] syringe
# 408 New data! ['honey', 'board'] cheese
# 409 New data! ['belt', 'skyscraper'] harness
# Cosine got it! 0.039119804400977995
# 410 New data! ['kangaroo', 'buck'] animal
# 411 New data! ['date', 'log'] calendar
# 412 New data! ['mouse', 'tail'] rat
# Euclidean got it! 0.1820388349514563
# Cosine got it! 0.0412621359223301
# 413 New data! ['rabbit', 'plot'] garden
# 414 New data! ['pupil', 'dinosaur'] schoolboy
# 415 New data! ['press', 'band'] tour
# 416 New data! ['washer', 'glass'] dish
# 417 New data! ['state', 'mount'] colorado
# 418 New data! ['mount', 'eye'] view
# 419 New data! ['germany', 'death'] nazi
# 420 New data! ['model', 'pyramid'] geometric
# 421 New data! ['grass', 'capital'] estate
# 422 New data! ['stream', 'life'] water
# 423 New data! ['lead', 'racket'] weapon
# 424 New data! ['screen', 'jupiter'] scifi
# 425 New data! ['wave', 'cell'] solar
# 426 New data! ['rome', 'ruler'] caesar
# Euclidean got it! 0.1784037558685446
# 427 New data! ['spot', 'mexico'] vacation
# 428 New data! ['tooth', 'hawk'] beak
# 429 New data! ['bar', 'bridge'] steel
# 430 New data! ['bolt', 'pole'] sprint
# 431 New data! ['novel', 'game'] clue
# Euclidean got it! 0.17865429234338748
# 432 New data! ['pool', 'hollywood'] grotto
# 433 New data! ['paper', 'key'] test
# 434 New data! ['mole', 'buffalo'] animal
# 435 New data! ['queen', 'alien'] fairy
# 436 New data! ['buck', 'pin'] atm
# 437 New data! ['draft', 'suit'] recruit
# 438 New data! ['bottle', 'night'] club
# 439 New data! ['pin', 'dress'] tailor
# 440 New data! ['press', 'diamond'] pressure
# 441 New data! ['organ', 'fan'] concert
# 442 New data! ['fire', 'lion'] orange
# 443 New data! ['code', 'lead'] vault
# 444 New data! ['fork', 'orange'] eat
# 445 New data! ['scale', 'spot'] beauty
# 446 New data! ['calf', 'bottle'] milk
# Euclidean got it! 0.17488789237668162
# 447 New data! ['queen', 'shot'] archer
# 448 New data! ['light', 'skyscraper'] horizon
# Euclidean got it! 0.17633928571428573
# 449 New data! ['server', 'ice'] cocktail
# 450 New data! ['spider', 'string'] web
# 451 New data! ['plot', 'hawk'] trajectory
# 452 New data! ['tokyo', 'mint'] yen
# 453 New data! ['ruler', 'jet'] weed
# 454 New data! ['apple', 'vet'] doctor
# 455 New data! ['hook', 'slip'] fish
# 456 New data! ['spell', 'key'] skeleton
# 457 New data! ['roulette', 'beijing'] macau
# 458 New data! ['hole', 'film'] plot
# 459 New data! ['novel', 'pool'] mermaid
# 460 New data! ['heart', 'mouth'] body
# 461 New data! ['tube', 'bottle'] toothpaste
# 462 New data! ['drop', 'nut'] extract
# 463 New data! ['slug', 'tag'] touch
# 464 New data! ['figure', 'gas'] matter
# Euclidean got it! 0.1724137931034483
# 465 New data! ['cold', 'greece'] gelato
# 466 New data! ['bolt', 'palm'] shock
# 467 New data! ['night', 'racket'] noisy
# 468 New data! ['rock', 'cycle'] tour
# 469 New data! ['iron', 'arm'] curl
# 470 New data! ['dwarf', 'boot'] armor
# 471 New data! ['light', 'club'] neon
# 472 New data! ['tokyo', 'crown'] dynasty
# 473 New data! ['tie', 'fork'] banquet
# 474 New data! ['buck', 'gold'] cash
# 475 New data! ['iron', 'centaur'] warrior
# Euclidean got it! 0.1705263157894737
# 476 New data! ['temple', 'snowman'] monument
# 477 New data! ['fly', 'organ'] noisy
# 478 New data! ['force', 'plate'] tectonic
# 479 New data! ['pilot', 'fish'] submarine
# 480 New data! ['leprechaun', 'berlin'] fairytale
# 481 New data! ['bark', 'battery'] park
# 482 New data! ['mammoth', 'octopus'] creature
# Euclidean got it! 0.17012448132780084
# 483 New data! ['dinosaur', 'switch'] eclipse
# 484 New data! ['point', 'laser'] presentation
# 485 New data! ['church', 'state'] institution
# Euclidean got it! 0.1711340206185567
# 486 New data! ['jet', 'time'] eta
# 487 New data! ['copper', 'chick'] penny
# Euclidean got it! 0.17248459958932238
# 488 New data! ['hole', 'fall'] pit
# 489 New data! ['alien', 'crown'] forehead
# 490 New data! ['beat', 'stadium'] game
# 491 New data! ['leprechaun', 'beach'] rainbow
# Euclidean got it! 0.17311608961303462
# 492 New data! ['penguin', 'dragon'] creature
# Euclidean got it! 0.17479674796747968
# 493 New data! ['strike', 'compound'] raid
# 494 New data! ['pumpkin', 'palm'] carve
# Cosine got it! 0.03643724696356275
# 495 New data! ['pupil', 'novel'] reading
# Euclidean got it! 0.17575757575757575
# 496 New data! ['limousine', 'sound'] prom
# Cosine got it! 0.038306451612903226
# 497 New data! ['shark', 'game'] hockey
# 498 New data! ['block', 'deck'] build
# 499 New data! ['dwarf', 'compound'] ore
# 500 New data! ['casino', 'ring'] table
# 501 New data! ['horn', 'greece'] pan
# 502 New data! ['engine', 'box'] motor
# Cosine got it! 0.0398406374501992
# 503 New data! ['apple', 'kiwi'] fruit
# Euclidean got it! 0.1749502982107356
# 504 New data! ['phoenix', 'day'] renew
# 505 New data! ['dance', 'china'] acrobat
# 506 New data! ['witch', 'bill'] brim
# 507 New data! ['fair', 'china'] trade
# Euclidean got it! 0.1755424063116371
# 508 New data! ['flute', 'rock'] music
# Euclidean got it! 0.17716535433070865
# 509 New data! ['soldier', 'net'] safety
# 510 New data! ['star', 'oil'] energy
# 511 New data! ['film', 'bottle'] message
# 512 New data! ['nail', 'lead'] metal
# 513 New data! ['tie', 'fish'] net
# 514 New data! ['bomb', 'conductor'] symphonic
# 515 New data! ['net', 'amazon'] fish
# 516 New data! ['bug', 'lawyer'] rat
# 517 New data! ['water', 'queen'] chalice
# 518 New data! ['triangle', 'princess'] pendant
# 519 New data! ['tie', 'part'] suit
# 520 New data! ['mercury', 'water'] liquid
# Euclidean got it! 0.175
# 521 New data! ['hook', 'plot'] pirate
# 522 New data! ['hand', 'shakespeare'] gesture
# 523 New data! ['church', 'jupiter'] god
# 524 New data! ['sound', 'jack'] aux
# 525 New data! ['princess', 'pumpkin'] cinderella
# Euclidean got it! 0.17523809523809525
# Cosine got it! 0.04
# 526 New data! ['mouth', 'fork'] eat
# 527 New data! ['fair', 'lap'] race
# 528 New data! ['pirate', 'america'] columbus
# Euclidean got it! 0.17613636363636365
# 529 New data! ['mint', 'string'] floss
# 530 New data! ['knife', 'force'] stab
# Euclidean got it! 0.17735849056603772
# 531 New data! ['sub', 'angel'] float
# 532 New data! ['gold', 'ice'] bling
# 533 New data! ['line', 'pistol'] sight
# Euclidean got it! 0.17823639774859287
# 534 New data! ['giant', 'cat'] tiger
# Euclidean got it! 0.1797752808988764
# 535 New data! ['paper', 'hotel'] notepad
# 536 New data! ['suit', 'life'] style
# 537 New data! ['casino', 'laser'] heist
# 538 New data! ['racket', 'bank'] money
# Euclidean got it! 0.18029739776951673
# 539 New data! ['boom', 'screen'] platoon
# 540 New data! ['bill', 'church'] tithe
# 541 New data! ['center', 'code'] software
# 542 New data! ['amazon', 'shoe'] zappos
# 543 New data! ['buck', 'pitch'] throw
# 544 New data! ['jam', 'slip'] injure
# 545 New data! ['fighter', 'ring'] boxing
# Euclidean got it! 0.1798165137614679
# 546 New data! ['triangle', 'field'] diamond
# 547 New data! ['scientist', 'space'] nasa
# Euclidean got it! 0.1809872029250457
# 548 New data! ['gas', 'luck'] jackpot
# 549 New data! ['ninja', 'dragon'] asia
# 550 New data! ['square', 'genius'] apple
# 551 New data! ['park', 'racket'] tennis
# Euclidean got it! 0.18148820326678766
# 552 New data! ['chest', 'pirate'] treasure
# Euclidean got it! 0.18297101449275363
# 553 New data! ['phoenix', 'organ'] renew
# 554 New data! ['force', 'mouth'] yell
# 555 New data! ['centaur', 'tower'] tall
# 556 New data! ['spike', 'wake'] impulse
# 557 New data! ['bermuda', 'whale'] ocean
# Euclidean got it! 0.18312387791741472
# 558 New data! ['canada', 'plane'] tundra
# 559 New data! ['beach', 'lawyer'] fishy
# 560 New data! ['triangle', 'compound'] pentagon
# 561 New data! ['water', 'shadow'] reflection
# 562 New data! ['horn', 'genius'] heady
# 563 New data! ['hawk', 'mercury'] sky
# 564 New data! ['engine', 'giant'] truck
# Euclidean got it! 0.18262411347517732
# 565 New data! ['change', 'millionaire'] money
# Euclidean got it! 0.184070796460177
# 566 New data! ['figure', 'yard'] scarecrow
# 567 New data! ['kangaroo', 'ghost'] creature
# 568 New data! ['eye', 'greece'] oracle
# 569 New data! ['bill', 'head'] hat
# 570 New data! ['thumb', 'board'] tack
# 571 New data! ['game', 'plane'] toy
# 572 New data! ['duck', 'mouth'] bill
# 573 New data! ['missile', 'cook'] heat
# 574 New data! ['straw', 'fan'] paper
# 575 New data! ['table', 'pan'] kitchen
# 576 New data! ['greece', 'war'] trojan
# 577 New data! ['ketchup', 'rabbit'] food
# 578 New data! ['degree', 'pass'] graduate
# Euclidean got it! 0.18166089965397925
# Cosine got it! 0.03806228373702422
# 579 New data! ['charge', 'eagle'] ambush
# 580 New data! ['dance', 'tick'] jitter
# 581 New data! ['berlin', 'bottle'] beer
# Euclidean got it! 0.18244406196213425
# 582 New data! ['racket', 'diamond'] court
# 583 New data! ['theater', 'europe'] opera
# Cosine got it! 0.03945111492281304
# 584 New data! ['bed', 'hospital'] sick
# Euclidean got it! 0.1832191780821918
# 585 New data! ['embassy', 'drop'] spy
# 586 New data! ['czech', 'film'] auteur
# 587 New data! ['pirate', 'africa'] caribbean
# Euclidean got it! 0.1839863713798978
# 588 New data! ['pupil', 'pound'] tuition
# 589 New data! ['rock', 'penguin'] berg
# 590 New data! ['dragon', 'king'] medieval
# 591 New data! ['park', 'amazon'] forest
# Euclidean got it! 0.1844331641285956
# 592 New data! ['greece', 'bermuda'] coastal
# 593 New data! ['ball', 'play'] game
# Euclidean got it! 0.18549747048903878
# 594 New data! ['play', 'turkey'] football
# 595 New data! ['port', 'shot'] canon
# 596 New data! ['bolt', 'trunk'] lock
# Euclidean got it! 0.18624161073825504
# 597 New data! ['stock', 'spring'] sale
# 598 New data! ['spell', 'chocolate'] halloween
# 599 New data! ['plot', 'button'] hole
# 600 New data! ['princess', 'pirate'] character
# 601 New data! ['forest', 'europe'] castle
# 602 New data! ['knight', 'king'] medieval
# 603 New data! ['soldier', 'box'] toy
# 604 New data! ['bed', 'tie'] kinky
# 605 New data! ['scientist', 'trip'] fieldwork
# 606 New data! ['staff', 'oil'] rig
# 607 New data! ['undertaker', 'palm'] boxer
# 608 New data! ['yard', 'battery'] park
# 609 New data! ['chest', 'port'] pirate
# 610 New data! ['agent', 'moscow'] kgb
# Euclidean got it! 0.18360655737704917
# 611 New data! ['centaur', 'buck'] forest
# 612 New data! ['kid', 'bed'] bunk
# 613 New data! ['antarctica', 'car'] plow
# 614 New data! ['life', 'wave'] pulse
# 615 New data! ['port', 'life'] toast
# 616 New data! ['hollywood', 'space'] interstellar
# 617 New data! ['point', 'mercury'] temperature
# 618 New data! ['horn', 'apple'] cornucopia
# 619 New data! ['vet', 'drop'] medicine
# 620 New data! ['spot', 'africa'] sun
# 621 New data! ['track', 'pit'] tar
# 622 New data! ['stick', 'fire'] camp
# 623 New data! ['nail', 'hook'] metal
# 624 New data! ['temple', 'palm'] prayer
# 625 New data! ['center', 'tooth'] root
# 626 New data! ['pupil', 'plate'] round
# 627 New data! ['hollywood', 'bow'] stage
# 628 New data! ['soul', 'hospital'] death
# Euclidean got it! 0.17993630573248406
# 629 New data! ['game', 'orange'] basketball
# 630 New data! ['shadow', 'ray'] sun
# 631 New data! ['pirate', 'night'] raid
# 632 New data! ['code', 'degree'] cs
# 633 New data! ['genius', 'pirate'] napster
# 634 New data! ['cast', 'millionaire'] actor
# Euclidean got it! 0.17981072555205047
# 635 New data! ['face', 'pole'] totem
# 636 New data! ['skyscraper', 'square'] business
# 637 New data! ['mail', 'conductor'] delivery
# Cosine got it! 0.03767660910518053
# 638 New data! ['laser', 'note'] highlight
# Euclidean got it! 0.18025078369905956
# 639 New data! ['pound', 'pyramid'] stone
# 640 New data! ['thumb', 'doctor'] broken
# Euclidean got it! 0.18125
# 641 New data! ['concert', 'row'] seat
# 642 New data! ['mouth', 'tube'] toothpaste
# 643 New data! ['cloak', 'cell'] stealth
# 644 New data! ['belt', 'log'] saw
# Euclidean got it! 0.18167701863354038
# 645 New data! ['nail', 'shadow'] hang
# 646 New data! ['lead', 'oil'] resource
# 647 New data! ['mine', 'beat'] heart
# 648 New data! ['face', 'foot'] body
# 649 New data! ['yard', 'pie'] pumpkin
# Euclidean got it! 0.18181818181818182
# 650 New data! ['cap', 'superhero'] costume
# 651 New data! ['face', 'bark'] mouth
# 652 New data! ['point', 'pistol'] aim
# Euclidean got it! 0.18251533742331288
# 653 New data! ['card', 'fighter'] boxing
# 654 New data! ['charge', 'board'] particle
# 655 New data! ['tokyo', 'ship'] export
# 656 New data! ['snow', 'code'] closure
# 657 New data! ['tooth', 'worm'] rot
# 658 New data! ['compound', 'centaur'] mixture
# Cosine got it! 0.037993920972644375
# 659 New data! ['hawk', 'ice'] diamond
# 660 New data! ['web', 'pumpkin'] halloween
# Euclidean got it! 0.18181818181818182
# 661 New data! ['thief', 'contract'] heist
# Cosine got it! 0.039334341906202726
# 662 New data! ['duck', 'kangaroo'] animal
# 663 New data! ['sub', 'tokyo'] water
# 664 New data! ['shadow', 'suit'] dark
# Euclidean got it! 0.1822289156626506
# Cosine got it! 0.04066265060240964
# 665 New data! ['fish', 'knight'] scale
# 666 New data! ['ninja', 'row'] fight
# 667 New data! ['witch', 'undertaker'] death
# 668 New data! ['tap', 'bark'] signal
# 669 New data! ['alien', 'pass'] paperwork
# 670 New data! ['snow', 'cover'] igloo
# 671 New data! ['tower', 'star'] skyward
# 672 New data! ['train', 'bow'] archery
# 673 New data! ['part', 'honey'] hive
# 674 New data! ['day', 'gold'] yellow
# 675 New data! ['press', 'orange'] juice
# 676 New data! ['state', 'microscope'] liquid
# 677 New data! ['game', 'microscope'] clue
# Euclidean got it! 0.18020679468242246
# 678 New data! ['casino', 'pilot'] aviator
# 679 New data! ['figure', 'charge'] cost
# Euclidean got it! 0.18114874815905743
# 680 New data! ['shark', 'angel'] glide
# 681 New data! ['chick', 'mount'] mare
# 682 New data! ['shark', 'crane'] animal
# 683 New data! ['wave', 'slug'] ripple
# Cosine got it! 0.040995607613469986
# 684 New data! ['helicopter', 'button'] eject
# 685 New data! ['whip', 'fly'] horse
# 686 New data! ['date', 'beat'] stroke
# 687 New data! ['litter', 'bed'] nursing
# 688 New data! ['cell', 'apple'] iphone
# Euclidean got it! 0.18023255813953487
# 689 New data! ['dog', 'drill'] dig
# Euclidean got it! 0.18142235123367198
# 690 New data! ['shot', 'force'] gun
# 691 New data! ['hotel', 'vet'] facility
# Euclidean got it! 0.18234442836468887
# 692 New data! ['stick', 'duck'] hunt
# Euclidean got it! 0.18352601156069365
# 693 New data! ['row', 'degree'] matrix
# 694 New data! ['wall', 'play'] curtain
# Cosine got it! 0.04178674351585014
# 695 New data! ['dog', 'star'] sirius
# 696 New data! ['lion', 'link'] leash
# 697 New data! ['wave', 'lap'] segment
# 698 New data! ['net', 'plastic'] safety
# 699 New data! ['eye', 'rock'] crystal
# 700 New data! ['poison', 'pistol'] kill
# Euclidean got it! 0.18285714285714286
# 701 New data! ['america', 'air'] flight
# 702 New data! ['gas', 'tap'] flow
# Euclidean got it! 0.18376068376068377
# 703 New data! ['scientist', 'tablet'] log
# 704 New data! ['eagle', 'spike'] talon
# Euclidean got it! 0.1846590909090909
# 705 New data! ['dress', 'button'] suit
# Euclidean got it! 0.18581560283687942
# 706 New data! ['bill', 'europe'] euro
# 707 New data! ['brush', 'horse'] mane
# 708 New data! ['soldier', 'buffalo'] frontier
# 709 New data! ['bar', 'lap'] rollercoaster
# 710 New data! ['space', 'ring'] saturn
# 711 New data! ['racket', 'stream'] paddle
# 712 New data! ['fork', 'mole'] chicken
# 713 New data! ['post', 'millionaire'] gate
# 714 New data! ['sink', 'water'] tap
# Euclidean got it! 0.18487394957983194
# 715 New data! ['bolt', 'pin'] nail
# 716 New data! ['pipe', 'england'] tobacco
# 717 New data! ['degree', 'watch'] circle
# 718 New data! ['bottle', 'file'] storage
# 719 New data! ['revolution', 'theater'] glory
# 720 New data! ['rabbit', 'suit'] wool
# 721 New data! ['oil', 'copper'] resource
# 722 New data! ['soldier', 'grace'] chaplain
# 723 New data! ['fork', 'suit'] dine
# 724 New data! ['trip', 'pirate'] ship
# Euclidean got it! 0.18370165745856354
# 725 New data! ['wind', 'horn'] orchestra
# 726 New data! ['knife', 'stream'] fishing
# 727 New data! ['laser', 'sound'] wave
# Euclidean got it! 0.1843191196698762
# 728 New data! ['heart', 'mouse'] mighty
# 729 New data! ['yard', 'dog'] fence
# Euclidean got it! 0.18518518518518517
# 730 New data! ['thumb', 'heart'] body
# 731 New data! ['chocolate', 'bear'] brown
# Euclidean got it! 0.18604651162790697
# 732 New data! ['crane', 'buck'] animal
# 733 New data! ['trip', 'car'] road
# 734 New data! ['calf', 'boom'] baby
# 735 New data! ['phoenix', 'eagle'] bird
# 736 New data! ['horse', 'beat'] whip
# 737 New data! ['mouth', 'ball'] spit
# Euclidean got it! 0.18588873812754408
# Cosine got it! 0.0407055630936228
# 738 New data! ['millionaire', 'paper'] cash
# 739 New data! ['america', 'africa'] continent
# Euclidean got it! 0.18673883626522328
# 740 New data! ['greece', 'berlin'] europe
# Euclidean got it! 0.18783783783783783
# 741 New data! ['trip', 'space'] ship
# 742 New data! ['ring', 'mouse'] cheese
# 743 New data! ['centaur', 'straw'] hay
# 744 New data! ['tap', 'roulette'] casino
# 745 New data! ['box', 'limousine'] hummer
# 746 New data! ['date', 'ball'] dance
# 747 New data! ['point', 'iron'] sword
# 748 New data! ['parachute', 'car'] travel
# 749 New data! ['tooth', 'turkey'] beak
# 750 New data! ['car', 'school'] bus
# Euclidean got it! 0.18666666666666668
# 751 New data! ['war', 'mount'] steed
# 752 New data! ['thief', 'ghost'] shady
# 753 New data! ['log', 'plastic'] material
# 754 New data! ['copper', 'roulette'] coin
# 755 New data! ['row', 'cross'] column
# Euclidean got it! 0.18675496688741722
# Cosine got it! 0.04105960264900662
# 756 New data! ['mole', 'horse'] animal
# Euclidean got it! 0.18783068783068782
# 757 New data! ['ground', 'whip'] punish
# 758 New data! ['nurse', 'cook'] tend
# 759 New data! ['dragon', 'chick'] fiona
# 760 New data! ['bank', 'ketchup'] blood
# 761 New data! ['mexico', 'missile'] mercury
# 762 New data! ['state', 'charge'] assert
# 763 New data! ['table', 'jam'] breakfast
# 764 New data! ['forest', 'log'] wood
# Euclidean got it! 0.18717277486910994
# 765 New data! ['cliff', 'church'] cottage
# 766 New data! ['pass', 'post'] basketball
# 767 New data! ['angel', 'hood'] church
# 768 New data! ['antarctica', 'microscope'] discovery
# Euclidean got it! 0.1875
# 769 New data! ['hollywood', 'tablet'] netflix
# 770 New data! ['bark', 'lab'] dog
# Euclidean got it! 0.18831168831168832
# 771 New data! ['hood', 'suit'] cloak
# 772 New data! ['quart', 'file'] container
# Euclidean got it! 0.18911917098445596
# 773 New data! ['button', 'eye'] round
# 774 New data! ['genius', 'soldier'] napoleon
# 775 New data! ['theater', 'mole'] agent
# 776 New data! ['olympus', 'boot'] climb
# 777 New data! ['lab', 'cloak'] coat
# Euclidean got it! 0.1891891891891892
# 778 New data! ['block', 'line'] shape
# 779 New data! ['doctor', 'straw'] swab
# 780 New data! ['strike', 'hospital'] nurse
# 781 New data! ['limousine', 'sound'] party
# 782 New data! ['deck', 'block'] wooden
# 783 New data! ['compound', 'berry'] jam
# 784 New data! ['tablet', 'knife'] edge
# Euclidean got it! 0.18877551020408162
# 785 New data! ['snow', 'washington'] mckinley
# 786 New data! ['olympus', 'embassy'] ruling
# 787 New data! ['death', 'piano'] wake
# 788 New data! ['undertaker', 'hospital'] death
# 789 New data! ['cycle', 'doctor'] life
# 790 New data! ['beach', 'bermuda'] vacation
# Euclidean got it! 0.18860759493670887
# 791 New data! ['foot', 'switch'] pedal
# 792 New data! ['track', 'moon'] orbit
# 793 New data! ['pupil', 'scientist'] college
# 794 New data! ['soul', 'mine'] oneself
# 795 New data! ['mouth', 'death'] choke
# 796 New data! ['film', 'pumpkin'] halloween
# Euclidean got it! 0.1884422110552764
# 797 New data! ['paste', 'jet'] model
# 798 New data! ['line', 'watch'] time
# Euclidean got it! 0.18922305764411027
# 799 New data! ['spike', 'needle'] prick
# 800 New data! ['rome', 'ghost'] past
# Euclidean got it! 0.19
# 801 New data! ['mercury', 'nail'] metal
# 802 New data! ['knight', 'horseshoe'] steed
# Cosine got it! 0.0399002493765586
# 803 New data! ['link', 'glove'] golfing
# 804 New data! ['star', 'saturn'] space
# 805 New data! ['tower', 'czech'] castle
# Euclidean got it! 0.19006211180124225
# Cosine got it! 0.040993788819875775
# 806 New data! ['fighter', 'tie'] empire
# 807 New data! ['bat', 'pipe'] smoke
# 808 New data! ['carrot', 'conductor'] motivator
# 809 New data! ['web', 'scorpion'] spider
# Euclidean got it! 0.1903584672435105
# 810 New data! ['tokyo', 'laser'] godzilla
# 811 New data! ['knife', 'jet'] soldier
# 812 New data! ['glass', 'concert'] harmony
# 813 New data! ['bow', 'cloak'] archer
# Euclidean got it! 0.1906519065190652
# 814 New data! ['light', 'fork'] utensil
# 815 New data! ['tap', 'tooth'] root
# 816 New data! ['himalayas', 'spring'] nepali
# Cosine got it! 0.041666666666666664
# 817 New data! ['saturn', 'scorpion'] astronomy
# Cosine got it! 0.042839657282741736
# 818 New data! ['water', 'mercury'] liquid
# Euclidean got it! 0.19070904645476772
# Cosine got it! 0.044009779951100246
# 819 New data! ['check', 'palm'] scanner
# 820 New data! ['hook', 'moscow'] eugene
# 821 New data! ['shakespeare', 'fighter'] tragic
# 822 New data! ['kid', 'sock'] pile
# 823 New data! ['dress', 'bat'] outfit
# Euclidean got it! 0.19076549210206561
# Cosine got it! 0.04495747266099635
# 824 New data! ['gold', 'sound'] bell
# 825 New data! ['check', 'block'] bank
# 826 New data! ['bridge', 'flute'] wood
# 827 New data! ['dress', 'suit'] gala
# 828 New data! ['fork', 'ball'] basket
# Euclidean got it! 0.19082125603864733
# 829 New data! ['knife', 'stick'] utensil
# Cosine got it! 0.045838359469240045
# 830 New data! ['force', 'mexico'] america
# Euclidean got it! 0.19156626506024096
# 831 New data! ['bark', 'paper'] tree
# Euclidean got it! 0.19253910950661854
# 832 New data! ['night', 'draft'] drunk
# 833 New data! ['leprechaun', 'jupiter'] walrus
# 834 New data! ['fire', 'duck'] splash
# 835 New data! ['pistol', 'germany'] prussia
# 836 New data! ['ice', 'calf'] painful
# 837 New data! ['centaur', 'stick'] arrow
# 838 New data! ['washington', 'crown'] jefferson
# Euclidean got it! 0.19212410501193317
# Cosine got it! 0.046539379474940336
# 839 New data! ['thumb', 'point'] palm
# 840 New data! ['stadium', 'moon'] arena
# Euclidean got it! 0.19285714285714287
# Cosine got it! 0.047619047619047616
# 841 New data! ['lap', 'pitch'] night
# 842 New data! ['heart', 'bill'] pass
# 843 New data! ['copper', 'pole'] stunt
# 844 New data! ['palm', 'track'] jamaican
# 845 New data! ['fair', 'leprechaun'] fairytale
# 846 New data! ['robot', 'sink'] shrink
# 847 New data! ['grass', 'time'] lawn
# Cosine got it! 0.048406139315230225
# 848 New data! ['atlantis', 'bermuda'] newfoundland
# 849 New data! ['germany', 'litter'] frankfurt
# Cosine got it! 0.04946996466431095
# 850 New data! ['staff', 'whip'] horseback
# 851 New data! ['life', 'undertaker'] thug
# 852 New data! ['hotel', 'bear'] cabin
# 853 New data! ['cell', 'bank'] branch
# Euclidean got it! 0.1910902696365768
# 854 New data! ['mouth', 'fish'] food
# Euclidean got it! 0.1920374707259953
# 855 New data! ['table', 'bow'] apron
# 856 New data! ['contract', 'ship'] partner
# 857 New data! ['dress', 'sound'] silhouette
# 858 New data! ['deck', 'shark'] boat
# Euclidean got it! 0.19230769230769232
# 859 New data! ['tokyo', 'olympus'] island
# 860 New data! ['atlantis', 'code'] cipher
# 861 New data! ['school', 'bill'] proposal
# Euclidean got it! 0.19279907084785133
# 862 New data! ['london', 'skyscraper'] tower
# Euclidean got it! 0.1937354988399072
# 863 New data! ['figure', 'whip'] circle
# 864 New data! ['charge', 'web'] phone
# 865 New data! ['soldier', 'pass'] survive
# 866 New data! ['america', 'engine'] motor
# 867 New data! ['bear', 'horse'] poop
# 868 New data! ['bow', 'organ'] harp
# Euclidean got it! 0.1935483870967742
# 869 New data! ['skyscraper', 'crash'] explode
# 870 New data! ['france', 'pipe'] renault
# 871 New data! ['dance', 'ninja'] stunt
# 872 New data! ['england', 'missile'] yorkshire
# Cosine got it! 0.04931192660550459
# 873 New data! ['teacher', 'ivory'] mentor
# Euclidean got it! 0.19358533791523483
# Cosine got it! 0.050400916380297825
# 874 New data! ['greece', 'flute'] hellenic
# 875 New data! ['soldier', 'log'] routine
# 876 New data! ['park', 'fair'] yard
# 877 New data! ['paste', 'death'] toxic
# 878 New data! ['shadow', 'octopus'] underworld
# 879 New data! ['ruler', 'ground'] measurement
# 880 New data! ['theater', 'tower'] workshop
# 881 New data! ['track', 'bear'] sensor
# 882 New data! ['seal', 'mail'] food
# Euclidean accuracy is 0.19160997732426305
# Cosine accuracy is 0.049886621315192746
# Random accuray is! 0.0
